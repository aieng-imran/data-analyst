# %% [markdown]
# # Operators
#
# 1) Regular & Boolean Operators
#
# 2) Numpy- Logical Operators
#
# 3) Nestedif
#
# 4) Filtering pandas DataFrames

# %%
# https://www.programiz.com/python-programming/if-elif-else

# %%
import numpy as np
np_height = np.array([1.73, 1.68, 1.71, 1.89, 1.79])
np_weight = np.array([65.4, 59.2, 63.6, 88.4, 68.7])
bmi = np_weight / np_height ** 2
bmi
# Out:
# array([21.85171573, 20.97505669, 21.75028214, 24.7473475 , 21.44127836])

# %%
bmi < 23
# Out:
# array([ True,  True,  True, False,  True])

# %% [markdown]
# ![Operators.PNG](attachment:Operators.PNG)

# %%
bmi > 21 and bmi < 22
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10280/2264849566.py in <module>
# ----> 1 bmi > 21 and bmi < 22
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# ![Numpy%20Logical%20Operators.PNG](attachment:Numpy%20Logical%20Operators.PNG)

# %% [markdown]
# # import numpy as np

# %%
import numpy as np
np.logical_and(bmi > 21, bmi < 22)
# Out:
# array([ True, False,  True, False,  True])

# %%
bmi[np.logical_and(bmi > 21, bmi < 22)]
# Out:
# array([21.85171573, 21.75028214, 21.44127836])

# %%
np.logical_or(bmi > 21, bmi < 22)
# Out:
# array([ True,  True,  True,  True,  True])

# %%
bmi[np.logical_or(bmi > 21, bmi < 22)]
# Out:
# array([21.85171573, 20.97505669, 21.75028214, 24.7473475 , 21.44127836])

# %%
np.logical_not(bmi > 21, bmi < 22)
# Out:
# array([False,  True, False, False, False])

# %%
bmi[np.logical_not(bmi > 21, bmi < 22)]
# Out:
# array([20.97505669])

# %% [markdown]
# ## Flow Control

# %% [markdown]
# ### If Statement

# %% [markdown]
# ![IF%20statement.PNG](attachment:IF%20statement.PNG)

# %%
num = 5

if num > 2:
    print("I won!")
print("I am happy:)")
# Out:
# I won!
# I am happy:)

# %% [markdown]
# ###  if..else Statement

# %% [markdown]
# ![If%20Else%20statement.PNG](attachment:If%20Else%20statement.PNG)

# %%
num = 5

if num > 2:
    print("I won!")
else:
    print("Try again")
# Out:
# I won!

# %% [markdown]
# # if...elif...else

# %% [markdown]
# ![If%20else%20elif.PNG](attachment:If%20else%20elif.PNG)

# %%
num = 15

if num > 20:
    print("I won!")
elif num > 10:
    print("You can win!")
else:
    print("Try again!")
# Out:
# You can win!

# %% [markdown]
# ### Nested If

# %%
'''In this program, we input a number
check if the number is positive or
negative or zero and display
an appropriate message
This time we use nested if statement'''

num = float(input("Enter a number: "))
if num >= 0:
    if num == 0:
        print("Zero")
    else:
        print("Positive number")
else:
    print("Negative number")
# Out:
# Enter a number: -10
# Negative number

# %% [markdown]
# ### Filtering pandas DataFrames

# %% [markdown]
# ![Challenge.PNG](attachment:Challenge.PNG)

# %%
import pandas as pd
brics = pd.read_csv('./Data/brics.csv', index_col = 0)
brics.head()
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
desired_area = brics['area'] > 8

# %%
brics[desired_area]
# Out:
#    country   capital    area  population
# BR  Brazil  Brasilia   8.516       200.4
# RU  Russia    Moscow  17.100       143.5
# CH   China   Beijing   9.597      1357.0

# %%
import numpy as np
np.logical_and(brics['area'] > 8, brics['area'] < 10)
# Out:
# BR     True
# RU    False
# IN    False
# CH     True
# SA    False
# Name: area, dtype: bool

# %%
brics[np.logical_and(brics['area'] > 8, brics['area'] < 10)]
# Out:
#    country   capital   area  population
# BR  Brazil  Brasilia  8.516       200.4
# CH   China   Beijing  9.597      1357.0
