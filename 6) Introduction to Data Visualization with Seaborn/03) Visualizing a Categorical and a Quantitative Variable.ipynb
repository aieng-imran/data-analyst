# %% [markdown]
# # Count plots and bar plots
#
# 1) Count vs Cat plot()
#
# 2) Bar Chart
#
# 3) Box Plot
#
# 4) Point Plots

# %%
"""
Just like we used "relplot()" to create different types of relational plots,
in this chapter we'll be using "catplot()" to create different types of 
categorical plots. "catplot()" offers the same flexibility that "relplot()" 
does, which means it will be easy to create subplots if we need to using the
same "col" and "row" parameters.

"""
# Out:
# '\nJust like we used "relplot()" to create different types of relational plots,\nin this chapter we\'ll be using "catplot()" to create different types of \ncategorical plots. "catplot()" offers the same flexibility that "relplot()" \ndoes, which means it will be easy to create subplots if we need to using the\nsame "col" and "row" parameters.\n\n'

# %% [markdown]
# ![catplot.PNG](attachment:catplot.PNG)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('./Data/young-people-survey-responses.csv', index_col = 0)

print(df.head(2))
# Out:
#         day  Music  Techno  Movies  History  Mathematics  Pets  Spiders  \
# 0  Thursday    5.0     1.0     5.0      1.0          3.0   4.0      1.0
# 1    Friday    4.0     1.0     5.0      1.0          5.0   5.0      1.0
#
#    Loneliness  Parents' advice   Internet usage  Finances   Age  Siblings  \
# 0         3.0              4.0  few hours a day       3.0  20.0       1.0
# 1         2.0              2.0  few hours a day       3.0  19.0       2.0
#
#    Gender Village - town
# 0  female        village
# 1  female           city

# %% [markdown]
# ### countplot() vs. catplot()

# %% [markdown]
# ![Count%20vs%20Cat%20plot.PNG](attachment:Count%20vs%20Cat%20plot.PNG)

# %% [markdown]
# ### Count Plot

# %%
sns.countplot(x="Internet usage", data = df)
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# ### Cat Plot

# %%
sns.catplot(x="Internet usage", data = df, kind = "count")
plt.xticks(rotation= 90)
plt.show()

# %%
# Changing the order  (One can change the order manually. Refer to Chapter 3 pdf notes)

# %% [markdown]
# ### Bar Plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('./Data/young-people-survey-responses.csv', index_col = 0)

df.head()
# Out:
#         day  Music  Techno  Movies  History  Mathematics  Pets  Spiders  \
# 0  Thursday    5.0     1.0     5.0      1.0          3.0   4.0      1.0
# 1    Friday    4.0     1.0     5.0      1.0          5.0   5.0      1.0
# 2  Saturday    5.0     1.0     5.0      1.0          5.0   5.0      1.0
# 3    Sunday    5.0     2.0     5.0      4.0          4.0   1.0      5.0
# 4    Monday    5.0     2.0     5.0      3.0          2.0   1.0      1.0
#
#    Loneliness  Parents' advice   Internet usage  Finances   Age  Siblings  \
# 0         3.0              4.0  few hours a day       3.0  20.0       1.0
# 1         2.0              2.0  few hours a day       3.0  19.0       2.0
# 2         5.0              3.0  few hours a day       2.0  20.0       2.0
# 3         5.0              2.0  most of the day       2.0  22.0       1.0
# 4         3.0              3.0  few hours a day       4.0  20.0       1.0
#
#    Gender Village - town
# 0  female        village
# 1  female           city
# ...

# %%
sns.catplot(x="day", y = "Mathematics", data = df, kind = "bar")
plt.xticks(rotation= 90)
plt.show()

# %%
"""
Bar plots look similar to count plots, but instead of the count of 
observations in each category, they show the mean of a quantitative 
variable among observations in each category.  

"""
# Out:
# '\nBar plots look similar to count plots, but instead of the count of \nobservations in each category, they show the mean of a quantitative \nvariable among observations in each category.  \n\n'

# %%
 # Turning OFF Confidence Interval
    
sns.catplot(x="day", y = "Music", data = df, kind = "bar", ci =  None)
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# ## Box Plot

# %%
sns.catplot(x="day", y = "Mathematics", data = df, kind = "box")
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# ![Whis.PNG](attachment:Whis.PNG)

# %%
sns.catplot(x="day", y = "Mathematics", data = df, kind = "box", whis = [0, 100])
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# ## Point plots

# %% [markdown]
# ![Point%20vs%20Line%20Plots.PNG](attachment:Point%20vs%20Line%20Plots.PNG)

# %% [markdown]
# ![Point%20vs%20Bar%20Plot.PNG](attachment:Point%20vs%20Bar%20Plot.PNG)

# %%
sns.catplot(x="day", y = "Mathematics", data = df, kind = "point")
plt.xticks(rotation= 90)
plt.show()
