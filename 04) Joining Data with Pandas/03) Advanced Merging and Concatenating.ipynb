# %% [markdown]
# # Advanced Merging and Concatenating
#
# 1) Filtering joins
#
# 2) Semi-Join
#
# 3) Anti- Join
#
# 4) Concatenate DataFrames together vertically
#
# 5) Verifying integrity

# %%
# How to combine DataFrames in Pandas | Merge, Join, Concat, & Append
# https://www.youtube.com/watch?v=wzN1UyfRSWI

# %% [markdown]
# ![Mutating%20vs%20Filtering%20Joins.PNG](attachment:Mutating%20vs%20Filtering%20Joins.PNG)

# %% [markdown]
# ### Semi- Join

# %% [markdown]
# ![semi-join.PNG](attachment:semi-join.PNG)

# %%
import pandas as pd

ratings = pd.read_pickle('./Data/ratings.p')
print(ratings.shape)
print(ratings.head())
# Out:
# (4803, 3)
#        id  vote_average  vote_count
# 0   19995           7.2     11800.0
# 1     285           6.9      4500.0
# 2  206647           6.3      4466.0
# 3   49026           7.6      9106.0
# 4   49529           6.1      2124.0

# %%
genres = pd.read_pickle('./Data/movie_to_genres.p')
print(genres.shape)
print(genres.head())
# Out:
# (12160, 2)
#    movie_id            genre
# 0         5            Crime
# 1         5           Comedy
# 2        11  Science Fiction
# 3        11           Action
# 4        11        Adventure
